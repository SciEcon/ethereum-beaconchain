# %% [markdown]
# # Part I: Set-up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Staking
# Out:
# /content/drive/MyDrive/Staking

# %%
import json
import pickle

import numpy as np
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# # Part II: Process the Validator Data

# %%
validators_json = (json
                   .load(open('data/validators.json', 'r'))
                   .get('data'))

# %%
# status: eligible, activated, exit
num_epochs = 156490 #beacon chain epoch start with number 0: https://ethscan.org/epochs
mat = np.zeros(shape=(num_epochs, 4), dtype=int) # for each epoch, identify the validators in 4 different states: 'eligible', 'activated', 'withdrawable', 'exited'

for validator in tqdm(validators_json):
    validator = validator.get('validator')
    slashed = validator.get('slashed')

    activation_eligibility_epoch = int(validator.get(
        'activation_eligibility_epoch'))
    activation_epoch = int(validator.get('activation_epoch'))
    withdrawable_epoch = int(validator.get('withdrawable_epoch'))
    exit_epoch = int(validator.get('exit_epoch'))

    payload = np.zeros(shape=(num_epochs, 4), dtype=int) #for each validator, add +1 to the validator state it belongs for each epoch

    if activation_eligibility_epoch < num_epochs:
        payload[activation_eligibility_epoch:, 0] = 1 # the validator has been eligible since the activation_eligibility_epoch
    if activation_epoch < num_epochs: 
        payload[activation_epoch:, :] = 0 #the validator's eligible status end starting after activated since the activation_epoch
        payload[activation_epoch:, 1] = 1 #the validator has been activiated since the activation_epoch
    if withdrawable_epoch < num_epochs: 
        payload[withdrawable_epoch:, :] = 0 #the validator's activated status end after withdrawed since the withdrawable epoch
        payload[withdrawable_epoch:, 2] = 1 #the validator has been withdrawable since the withdrawable_epoch
    if exit_epoch < num_epochs: 
        payload[exit_epoch:, :] = 0 #the validator's withdrawable status end after exited since the exit_epoch
        payload[exit_epoch:, 3] = 1 #the validator has been exited since the exit_epoch
    mat += payload
# Out:
# 100%|██████████| 533448/533448 [26:18<00:00, 337.99it/s]

# %%
status_df = pd.DataFrame(
    mat, columns=['eligible', 'activated', 'withdrawable', 'exited'])

# %%
status_df.head()
# Out:
#    eligible  activated  withdrawable  exited
# 0         0      21063             0       0
# 1         0      21063             0       0
# 2         0      21063             0       0
# 3         0      21063             0       0
# 4         0      21063             0       0

# %%
status_df.tail()
# Out:
#         eligible  activated  withdrawable  exited
# 156485       304     452218             0     917
# 156486       298     452224             0     917
# 156487       292     452230             0     917
# 156488       286     452236             0     917
# 156489       280     452242             0     917

# %%
status_df.to_csv('data/status.csv')

# %% [markdown]
# # Part III: Process the Beacon Chain Block Data

# %% [markdown]
# Note: need high-RAM runtime

# %%
block_df = pd.read_json('output/beacon_blocks.json', lines=True)

# %%
block_df.head()
# Out:
#       item_type  block_slot  block_epoch       block_timestamp  \
# 0  beacon_block     4680002       146250  2022-09-12T12:00:47Z
# 1  beacon_block     4680004       146250  2022-09-12T12:01:11Z
# 2  beacon_block     4680000       146250  2022-09-12T12:00:23Z
# 3  beacon_block     4680001       146250  2022-09-12T12:00:35Z
# 4  beacon_block     4680003       146250  2022-09-12T12:00:59Z
#
#    proposer_index  skipped  block_root  \
# 0        373276.0    False         NaN
# 1        211305.0    False         NaN
# 2         41984.0    False         NaN
# 3        179498.0    False         NaN
# 4        226424.0    False         NaN
#
#                                          parent_root  \
# 0  0xe9442499af2b521c7b53ff476d01436c967ffa956278...
# 1  0xa9d740adfb11d9b61e2923fbb4446d5982ba57aafb86...
# 2  0x4489d44916f6e2208f6432f83c327f2955135d476f5a...
# 3  0xd899e67eec06d604933d83815f89a7b7daa92098b8f0...
# 4  0xef0660af1f8de5a5d0b5f025228a30f12f52a367af87...
#
#                                           state_root  \
# 0  0x490ba5390836bd6e956c62e19e3421185d6bff689a81...
# 1  0xd2c5de3d788cc500895422325f492b8833a3e42bcf90...
# 2  0x5a936c12d2fe860ed9fdfb26c9c9dd9205af624921c1...
# 3  0x246c6e1a94d1654f6d4ddfd84477c1f4c6dec7c3682a...
# 4  0xd0f4b324b67493eec5655c8865f0926cf89509e1990f...
#
#                                        randao_reveal  \
# 0  0x902597f35320a2ae53e99a8fac3fd1d414e8070d1825...
# 1  0xaf06cc5a0caa43565bcb3eef4287a9124100d13a7a70...
# 2  0x82d7f61f57d390bd4dc2daa42975614a09aa0c0eabe6...
# 3  0x9330ca45a6ccf2cc62067a5b79eac4c8ef338723f34a...
# 4  0xae31a0ffbc5b42e62bdce10e719664aae06898cb5707...
#
#                                             graffiti  \
# 0  0x4c69676874686f7573652f76332e312e302d61613032...
# 1  0x4b696c6e000000000000000000000000000000000000...
# 2  0x68756f6269706f6f6c00000000000000000000000000...
# 3  0x00000000000000000000000000000000000000000000...
# 4  0x00000000000000000000000000000000000000000000...
#
#                                      eth1_block_hash  \
# 0  0x9a14d9a48d6ccdc215ddbf1103e91b20a3bb0513614e...
# 1  0x9a14d9a48d6ccdc215ddbf1103e91b20a3bb0513614e...
# 2  0x9a14d9a48d6ccdc215ddbf1103e91b20a3bb0513614e...
# 3  0x9a14d9a48d6ccdc215ddbf1103e91b20a3bb0513614e...
# 4  0x9a14d9a48d6ccdc215ddbf1103e91b20a3bb0513614e...
#
#                                    eth1_deposit_root  eth1_deposit_count  \
# 0  0x309bd2edaa17edf01b0f6423ef04ff932770509e4ac8...            434383.0
# 1  0x309bd2edaa17edf01b0f6423ef04ff932770509e4ac8...            434383.0
# 2  0x309bd2edaa17edf01b0f6423ef04ff932770509e4ac8...            434383.0
# 3  0x309bd2edaa17edf01b0f6423ef04ff932770509e4ac8...            434383.0
# 4  0x309bd2edaa17edf01b0f6423ef04ff932770509e4ac8...            434383.0
#
#    signature                                       attestations deposits  \
# 0        NaN  [{'item_type': 'attestation', 'aggregation_bit...       []
# 1        NaN  [{'item_type': 'attestation', 'aggregation_bit...       []
# 2        NaN  [{'item_type': 'attestation', 'aggregation_bit...       []
# 3        NaN  [{'item_type': 'attestation', 'aggregation_bit...       []
# 4        NaN  [{'item_type': 'attestation', 'aggregation_bit...       []
#
#   proposer_slashings attester_slashings voluntary_exits
# 0                 []                 []              []
# 1                 []                 []              []
# 2                 []                 []              []
# 3                 []                 []              []
# 4                 []                 []              []

# %%
block_df_clean = block_df[[
    'block_slot', 'block_epoch', 'block_timestamp', 'proposer_index', 'eth1_deposit_count', 'attestations'
]]

# %%
block_df_clean = block_df_clean.dropna()
block_df_clean['block_timestamp'] = block_df_clean['block_timestamp'].astype(
    'datetime64[ns]')
block_df_clean['proposer_index'] = block_df_clean['proposer_index'].astype(int)
# Out:
# <ipython-input-7-4ca4d0a2637f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_df_clean['block_timestamp'] = block_df_clean['block_timestamp'].astype(
# <ipython-input-7-4ca4d0a2637f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   block_df_clean['proposer_index'] = block_df_clean['proposer_index'].astype(int)

# %%
pd.set_option('display.max_colwidth', None)
print(block_df_clean ["attestations"].head(1))
# Out:
# 0    [{'item_type': 'attestation', 'aggregation_bits': '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111', 'slot': 4680001, 'index': 10, 'beacon_block_root': '0xe9442499af2b521c7b53ff476d01436c967ffa956278dbe7baed5cff34d4a555', 'source_epoch': 146249, 'source_root': '0x13a52c9d5322d0492d9842bad66748d9773779d6697fd55f9eb1b261b24908dc', 'target_epoch': 146250, 'target_root': '0xd899e67eec06d604933d83815f89a7b7daa92098b8f0f8a2808070baf186f5b9', 'signature': '0x87cae57a4887d7187393ab6946a5c99e288fc90346011f71e04451b909855a712a7fa8c8905087717eb8a254a52130621758ff9e623e77315b3f8c6219d9fddd1b16233c8ea39d8625e780e7478cc690eff03cf096c4280f292e917836b40139'}, {'item_type': 'attestation', 'aggregation_bits': '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111', 'slot': 4680001, 'index': 11, 'beacon_block_root': '0xe9442499af2b521c7b53ff476d01436c967ffa956278dbe7baed5cff34d4a555', 'source_epoch': 146249, 'source_root': '0x13a52c9d5322d0492d9842bad66748d9773779d6697fd55f9eb1b261b24908dc', 'target_epoch': 146250, 'target_root': '0xd899e67eec06d604933d83815f89a7b7daa92098b8f0f8a2808070baf186f5b9', 'signature': '0xb0ecfc1a7e92dd1f584fa6570249c2d6cdd7d4adfda41edb0de2359ed1b2a39916baa3a87e4db7c07d740ee5bcd68d9703a20175144f98bf0fc5670822a46d854b3e136438c73f4000cbf9a7df001bc4f80d76d62d0c5a1907d2e61153d114b2'}, {'item_type': 'attestation', 'aggregation_bits': '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111', 'slot': 4680001, 'index': 21, 'beacon_block_root': '0xe9442499af2b521c7b53ff476d01436c967ffa956278dbe7baed5cff34d4a555', 'source_epoch': 146249, 'source_root': '0x13a52c9d5322d0492d9842bad66748d9773779d6697fd55f9eb1b261b24908dc', 'target_epoch': 146250, 'target_root': '0xd899e67eec06d604933d83815f89a7b7daa92098b8f0f8a2808070baf186f5b9', 'signature': '0xa8de25358990de07ad80814d9c117239b4e6eb1da05293f45175878ada54489ee99f985b79f96edd174a5d2263acc4530b9fcac86f9a86b2a0d4bf4d73d00d6640906e6712aeb8c3c0eeb3d2063319f935ede5f6a438475291d0b612d796f5c6'}, {'item_type': 'attestation', 'aggregation_bits': '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111', 'slot': 4680001, 'index': 49, 'beacon_block_root': '0xe9442499af2b521c7b53ff476d01436c967ffa956278dbe7baed5cff34d4a555', 'source_epoch': 146249, 'source_root': '0x13a52c9d5322d0492d9842bad66748d9773779d6697fd55f9eb1b261b24908dc', 'target_epoch': 146250, 'target_root': '0xd899e67eec06d604933d83815f89a7b7daa92098b8f0f8a2808070baf186f5b9', 'signature': '0xa23e9c96981b62df33795e83621b1d2f51711415f61a85c67ac3e710f91709f55c10bf24c4cba2d1fc9983354aeca4730fc61f8df234f6d93d06846e46a637cb7b53efe3bb7dd0d20104af84992fb4899f42f72dabc037cd25097223a0181d45'}, {'item_type': 'attestation', 'aggregation_bits': '1111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111111', 'slot': 4680001, 'index': 6, 'beacon_block_root': '0xe9442499af2b521c7b53ff476d01436c967ffa956278dbe7baed5cff34d4a555', 'source_epoch': 146249, 'source_root': '0x13a52c9d5322d0492d9842bad66748d9773779d6697fd55f9eb1b261b24908dc', 'target_epoch': 146250, 'target_root': '0xd899e67eec06d604933d83815f89a7b7daa92098b8f0f8a2808070baf186f5b9', 'signature': '0xa84f24b835595750a54eedc35a19fb44f539eb76451902a1ce8065e7f0fd0d50e9efcdd271821145a854051a0ce80e1c1358f8fb467ec373e15593d64b05ca1d1b6 ...
# Name: attestations, dtype: object

# %%
def get_attestation_num(lst):
    return len(lst)

block_df_clean['attestations_cnt'] = block_df_clean['attestations'].apply(get_attestation_num)

# %%
def get_attester_idx(lst):
    payload = []
    for item in lst:
        payload.append(item['index'])
    return payload

block_df_clean['attester'] = block_df_clean['attestations'].apply(get_attester_idx)

# %%
block_df_clean.head()
# Out:
#    block_slot  block_epoch     block_timestamp  proposer_index  \
# 0     4680002       146250 2022-09-12 12:00:47          373276
# 1     4680004       146250 2022-09-12 12:01:11          211305
# 2     4680000       146250 2022-09-12 12:00:23           41984
# 3     4680001       146250 2022-09-12 12:00:35          179498
# 4     4680003       146250 2022-09-12 12:00:59          226424
#
#    eth1_deposit_count                                       attestations  \
# 0            434383.0  [{'item_type': 'attestation', 'aggregation_bit...
# 1            434383.0  [{'item_type': 'attestation', 'aggregation_bit...
# 2            434383.0  [{'item_type': 'attestation', 'aggregation_bit...
# 3            434383.0  [{'item_type': 'attestation', 'aggregation_bit...
# 4            434383.0  [{'item_type': 'attestation', 'aggregation_bit...
#
#    attestations_cnt                                           attester
# 0                78  [10, 11, 21, 49, 6, 29, 3, 63, 5, 36, 42, 9, 3...
# 1                94  [19, 28, 44, 61, 31, 0, 21, 30, 16, 58, 5, 26,...
# 2                95  [35, 19, 42, 49, 13, 43, 44, 7, 37, 34, 26, 50...
# 3               128  [49, 59, 36, 34, 55, 60, 62, 9, 4, 54, 39, 3, ...
# 4               128  [63, 42, 41, 54, 0, 46, 52, 57, 38, 26, 36, 33...

# %%
block_df_clean.to_pickle('data/block_df.pkl')
