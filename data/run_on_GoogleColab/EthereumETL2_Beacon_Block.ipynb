# %% [markdown]
# Source: https://github.com/blockchain-etl/ethereum2-etl

# %% [markdown]
# # Part I: Set-up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Staking
# Out:
# /content/drive/MyDrive/Staking

# %%
pip install ethereum2-etl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ethereum2-etl in /usr/local/lib/python3.8/dist-packages (0.0.7)
# Requirement already satisfied: python-dateutil==2.7.0 in /usr/local/lib/python3.8/dist-packages (from ethereum2-etl) (2.7.0)
# Requirement already satisfied: click==7.0 in /usr/local/lib/python3.8/dist-packages (from ethereum2-etl) (7.0)
# Requirement already satisfied: blockchain-etl-common==1.4.0 in /usr/local/lib/python3.8/dist-packages (from ethereum2-etl) (1.4.0)
# Requirement already satisfied: requests==2.20.0 in /usr/local/lib/python3.8/dist-packages (from ethereum2-etl) (2.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil==2.7.0->ethereum2-etl) (1.15.0)
# Requirement already satisfied: idna<2.8,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests==2.20.0->ethereum2-etl) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests==2.20.0->ethereum2-etl) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests==2.20.0->ethereum2-etl) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests==2.20.0->ethereum2-etl) (2022.12.7)

# %% [markdown]
# # Part II: Query Ethereum Beacon Chain Block Data

# %% [markdown]
# Note 1: you need to add "!" in front of the sample code for it to run successfully in the Colab
#
# Note 2: you need to get an Ethereum node endpoint from a node provider such as quicknode. Please delete "/" at the end of the URL for it to work in the sample code.
#
# Note 3: you will find a newly generated folder named "output" under the current directory and a new file of data named "beacon_blocks.json" in the output folder.

# %%
# !ethereum2etl export_beacon_blocks --start-block 4680000 --end-block 4720000 --output-dir output --output-format json --provider-uri https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f
# Out:
# Streaming output truncated to the last 5000 lines.
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719641
# 2023-02-26 10:37:08,818 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:08,827 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719640
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719640
# 2023-02-26 10:37:08,827 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:08,833 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719642
# 2023-02-26 10:37:08,834 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:08,837 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719641
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719641
# 2023-02-26 10:37:08,837 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:08,843 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719643
# 2023-02-26 10:37:08,843 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:08,853 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719642
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719642
# 2023-02-26 10:37:08,906 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:08,862 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719643
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719643
# 2023-02-26 10:37:08,879 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719644
# 2023-02-26 10:37:08,908 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:08,907 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:08,928 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719644
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719644
# 2023-02-26 10:37:08,928 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:10,202 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719665
# 2023-02-26 10:37:10,204 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:10,229 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719666
# 2023-02-26 10:37:10,230 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719665
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719665
# 2023-02-26 10:37:10,230 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:10,230 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:10,240 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719667
# 2023-02-26 10:37:10,240 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:10,242 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719668
# 2023-02-26 10:37:10,243 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:10,245 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719669
# 2023-02-26 10:37:10,246 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:10,249 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719666
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719666
# 2023-02-26 10:37:10,318 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:10,260 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719667
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719667
# 2023-02-26 10:37:10,319 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:10,264 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719669
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
# ...
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719991
# 2023-02-26 10:37:29,205 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:29,206 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719993
# 2023-02-26 10:37:29,206 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:29,222 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719992
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719992
# 2023-02-26 10:37:29,255 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:29,247 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719994
# 2023-02-26 10:37:29,256 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2023-02-26 10:37:29,227 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719993
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719993
# 2023-02-26 10:37:29,258 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:29,276 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 62, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719994
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/blockchainetl_common/executors/batch_work_executor.py", line 103, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/jobs/export_beacon_blocks_job.py", line 61, in _export_batch
#     responses = list(self.ethereum2_service.get_beacon_blocks(slot_batch))
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 58, in get_beacon_blocks
#     raise e
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 52, in get_beacon_blocks
#     block_response = self.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/service/ethereum2_service.py", line 38, in get_beacon_block
#     return self.ethereum2_teku_api.get_beacon_block(slot)
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 36, in get_beacon_block
#     return self.get(f'/eth/v1/beacon/blocks/{slot}')
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/ethereum2_teku_api.py", line 48, in get
#     raw_response = make_get_request(
#   File "/usr/local/lib/python3.8/dist-packages/ethereum2etl/api/request.py", line 28, in make_get_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://ultra-chaotic-silence.discover.quiknode.pro/3a20380951ff287a674246a038a9563feea0e27f/eth/v1/beacon/blocks/4719994
# 2023-02-26 10:37:29,277 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2023-02-26 10:37:30,426 - ProgressLogger [INFO] - 40001 items processed. Progress is 100%.
# 2023-02-26 10:37:30,426 - ProgressLogger [INFO] - Finished work. Total items processed: 40001. Took 0:25:38.450652.
# 2023-02-26 10:37:30,429 - Ethereum2ItemExporter [INFO] - beacon_block items exported: 40001
